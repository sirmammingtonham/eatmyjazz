# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)

# %%
# !git clone https://github.com/sirmammingtonham/trading-fours
# Out:
# Cloning into 'trading-fours'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
# %cd trading-fours/
# Out:
# /content/trading-fours

# %%
# !unzip Jazz-Midi.tar.xz.zip
# Out:
# Archive:  Jazz-Midi.tar.xz.zip
#   inflating: Jazz-Midi.tar.xz

# %%
# !tar -xf Jazz-Midi.tar.xz

# %%
# %cd /content
# Out:
# /content

# %%
# !pip install mido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mido
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 2.7 MB/s
# Installing collected packages: mido
# Successfully installed mido-1.2.10

# %%
import mido

# %%
mid = mido.MidiFile('/content/trading-fours/Jazz Midi/5To10.mid', clip=True)
print(mid)
# Out:
# MidiFile(type=0, ticks_per_beat=120, tracks=[
#   MidiTrack([
#     MetaMessage('track_name', name='untitled', time=0),
#     MetaMessage('copyright', text='Copyright © 1996 by MANU.', time=0),
#     MetaMessage('text', text='MANU', time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('key_signature', key='C', time=0),
#     MetaMessage('set_tempo', tempo=375000, time=0),
#     Message('program_change', channel=9, program=40, time=0),
#     Message('program_change', channel=9, program=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=100, time=0),
#     Message('note_on', channel=9, note=57, velocity=100, time=0),
#     Message('program_change', channel=1, program=35, time=0),
#     Message('control_change', channel=1, control=7, value=127, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('program_change', channel=2, program=99, time=0),
#     Message('control_change', channel=2, control=7, value=70, time=0),
#     Message('note_on', channel=2, note=37, velocity=110, time=0),
#     Message('control_change', channel=2, control=93, value=127, time=0),
#     Message('program_change', channel=3, program=20, time=0),
#     Message('control_change', channel=3, control=7, value=35, time=0),
#     Message('note_on', channel=3, note=37, velocity=110, time=0),
#     Message('control_change', channel=3, control=93, value=127, time=0),
#     Message('program_change', channel=4, program=92, time=0),
#     Message('control_change', channel=4, control=7, value=80, time=0),
#     Message('control_change', channel=4, control=91, value=127, time=0),
#     Message('program_change', channel=4, program=92, time=0),
#     Message('control_change', channel=4, control=7, value=60, time=0),
#     Message('control_change', channel=4, control=91, value=127, time=0),
#     Message('note_on', channel=9, note=57, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('control_change', channel=4, control=91, value=126, time=2),
#     Message('control_change', channel=4, control=91, value=126, time=0),
#     Message('control_change', channel=4, control=91, value=125, time=4),
#     Message('control_change', channel=4, control=91, value=125, time=0),
#     Message('control_change', channel=4, control=91, value=127, time=2),
#     Message('control_change', channel=4, control=91, value=127, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=97),
#     Message('note_on', channel=9, note=46, velocity=100, time=1),
#     Message('note_on', channel=1, note=32, velocity=100, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=14),
#     Message('note_on', channel=1, note=32, velocity=0, time=45),
#     Message('note_on', channel=9, note=59, velocity=100, time=1),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('control_change', channel=4, control=93, value=127, time=46),
#     Message('control_change', channel=4, control=93, value=127, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=59),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=100, time=1),
#     Message('note_on', channel=9, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=44, velocity=100, time=46),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=51, velocity=100, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=2, note=37, velocity=0, time=45),
#     Message('note_on', channel=3, note=37, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=100, time=1),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=100, time=46),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=100, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=2, note=61, velocity=0, time=45),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=64, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=36, velocity=100, time=1),
#     Message('note_on', channel=9, note=51, velocity=100, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=100, time=60),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=59, velocity=60, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=59, velocity=100, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=42, velocity=60, time=46),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=9, note=42, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=100, time=46),
#     Message('note_on', channel=9, note=46, velocity=100, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=54, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=100, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=3, note=66, velocity=0, time=45),
#     Message('note_on', channel=1, note=37, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=64, time=1),
#     Message('note_on', channel=9, note=51, velocity=49, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=4, note=90, velocity=0, time=45),
#     Message('note_on', channel=4, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=100, time=1),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=3, note=59, velocity=0, time=45),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=47, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=3, note=66, velocity=0, time=15),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=99, time=31),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=36, velocity=64, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=44, velocity=80, time=46),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=2, note=63, velocity=0, time=45),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=59, time=1),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=36, velocity=64, time=1),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=47, time=1),
#     Message('note_on', channel=1, note=31, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=80, time=46),
#     Message('note_on', channel=9, note=40, velocity=80, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=2, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=1, note=31, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=50, time=1),
#     Message('note_on', channel=9, note=51, velocity=43, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=56, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=56, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=63, velocity=0, time=45),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=56, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=56, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=89, time=60),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=3, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=44, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=99, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=3, note=66, velocity=0, time=45),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=60, time=1),
#     Message('note_on', channel=9, note=44, velocity=80, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=45),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=9, note=59, velocity=59, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=70, time=1),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=45),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=60, time=46),
#     Message('note_on', channel=9, note=51, velocity=47, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=45),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=4),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=10),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=106),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=9, note=51, velocity=43, time=0),
#     Message('note_on', channel=1, note=33, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=3),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=11),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=44, velocity=89, time=106),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=2, note=59, velocity=0, time=45),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=1, note=33, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=9, note=51, velocity=44, time=0),
#     Message('note_on', channel=1, note=35, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=99, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=44, velocity=80, time=106),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=3, note=63, velocity=0, time=45),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=1, note=35, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=9, note=59, velocity=59, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=106),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=49, velocity=70, time=46),
#     Message('note_on', channel=9, note=51, velocity=47, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=4, note=81, velocity=100, time=0),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=69, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=59, velocity=99, time=1),
#     Message('note_on', channel=1, note=31, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=106),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=64, velocity=0, time=45),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=1, note=31, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=9, note=51, velocity=43, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=56, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=56, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=4, note=81, velocity=0, time=45),
#     Message('note_on', channel=4, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=4, note=69, velocity=0, time=0),
#     Message('note_on', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=1),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=61, velocity=0, time=45),
#     Message('note_on', channel=2, note=56, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=3, note=56, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=1),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=89, time=60),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=3, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=9, note=51, velocity=44, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=46),
#     Message('note_on', channel=9, note=51, velocity=99, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=45),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=1),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=60),
#     Message('note_on', channel=9, note=44, velocity=80, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=59, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=25, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=1, note=28, velocity=100, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=47, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=61, velocity=0, time=45),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=1, note=28, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=80, time=1),
#     Message('note_on', channel=1, note=31, velocity=100, time=0),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=43, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=80, time=46),
#     Message('note_on', channel=4, note=85, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_on', channel=4, note=73, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=80, time=46),
#     Message('note_on', channel=9, note=44, velocity=89, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=44, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=80, time=46),
#     Message('note_on', channel=9, note=51, velocity=99, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=0, time=105),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=1, note=31, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=80, time=1),
#     Message('note_on', channel=9, note=44, velocity=80, time=0),
#     Message('note_on', channel=1, note=36, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=2, note=71, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=71, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=59, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=90, time=46),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=4, note=88, velocity=100, time=0),
#     Message('note_on', channel=4, note=90, velocity=100, time=0),
#     Message('note_on', channel=4, note=95, velocity=100, time=0),
#     Message('note_on', channel=4, note=76, velocity=100, time=0),
#     Message('note_on', channel=4, note=78, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=47, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=106),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=43, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=38, velocity=50, time=26),
#     Message('note_on', channel=9, note=38, velocity=0, time=14),
#     Message('note_on', channel=9, note=48, velocity=121, time=26),
#     Message('note_on', channel=9, note=48, velocity=0, time=14),
#     Message('note_on', channel=9, note=48, velocity=121, time=26),
#     Message('note_on', channel=9, note=44, velocity=89, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=48, velocity=0, time=0),
#     Message('note_on', channel=9, note=48, velocity=60, time=26),
#     Message('note_on', channel=9, note=48, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=44, time=6),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=43, velocity=50, time=6),
#     Message('note_on', channel=9, note=43, velocity=0, time=14),
#     Message('note_on', channel=4, note=83, velocity=0, time=25),
#     Message('note_on', channel=3, note=64, velocity=0, time=0),
#     Message('note_on', channel=1, note=36, velocity=0, time=0),
#     Message('note_on', channel=4, note=88, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=3, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=78, velocity=0, time=0),
#     Message('note_on', channel=4, note=76, velocity=0, time=0),
#     Message('note_on', channel=4, note=90, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=95, velocity=0, time=0),
#     Message('note_on', channel=9, note=35, velocity=80, time=1),
#     Message('note_on', channel=9, note=51, velocity=99, time=0),
#     Message('note_on', channel=1, note=37, velocity=100, time=0),
#     Message('note_on', channel=2, note=37, velocity=110, time=0),
#     Message('note_on', channel=3, note=37, velocity=110, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=1, note=37, velocity=0, time=105),
#     Message('note_on', channel=9, note=44, velocity=80, time=1),
#     Message('note_on', channel=1, note=32, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=1, note=32, velocity=0, time=45),
#     Message('note_on', channel=9, note=40, velocity=90, time=1),
#     Message('note_on', channel=9, note=59, velocity=59, time=0),
#     Message('note_on', channel=1, note=25, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=57, velocity=100, time=0),
#     Message('note_on', channel=2, note=64, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=57, velocity=100, time=0),
#     Message('note_on', channel=3, note=64, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=3, note=64, velocity=0, time=45),
#     Message('note_on', channel=3, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=64, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=57, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=1),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=66, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=66, velocity=100, time=0),
#     Message('note_on', channel=9, note=35, velocity=80, time=60),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=35, velocity=0, time=0),
#     Message('note_on', channel=3, note=61, velocity=0, time=45),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=3, note=66, velocity=0, time=0),
#     Message('note_on', channel=2, note=66, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=47, time=1),
#     Message('note_on', channel=2, note=61, velocity=100, time=0),
#     Message('note_on', channel=2, note=63, velocity=100, time=0),
#     Message('note_on', channel=2, note=68, velocity=100, time=0),
#     Message('note_on', channel=3, note=61, velocity=100, time=0),
#     Message('note_on', channel=3, note=63, velocity=100, time=0),
#     Message('note_on', channel=3, note=68, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=3, note=37, velocity=0, time=45),
#     Message('note_on', channel=2, note=37, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=1),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=2, note=61, velocity=0, time=45),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
# ...
#     Message('note_on', channel=2, note=63, velocity=0, time=0),
#     Message('note_on', channel=4, note=85, velocity=0, time=0),
#     Message('note_on', channel=3, note=68, velocity=0, time=0),
#     Message('note_on', channel=3, note=63, velocity=0, time=0),
#     Message('note_on', channel=1, note=33, velocity=0, time=0),
#     Message('note_on', channel=4, note=75, velocity=0, time=0),
#     Message('note_on', channel=4, note=73, velocity=0, time=0),
#     Message('note_on', channel=4, note=87, velocity=0, time=0),
#     Message('note_on', channel=2, note=61, velocity=0, time=0),
#     Message('note_on', channel=2, note=68, velocity=0, time=0),
#     Message('note_on', channel=4, note=92, velocity=0, time=0),
#     Message('note_on', channel=9, note=57, velocity=79, time=1),
#     Message('note_on', channel=9, note=36, velocity=79, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=1, note=29, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=62, velocity=100, time=0),
#     Message('note_on', channel=2, note=65, velocity=100, time=0),
#     Message('note_on', channel=2, note=70, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=62, velocity=100, time=0),
#     Message('note_on', channel=3, note=65, velocity=100, time=0),
#     Message('note_on', channel=3, note=70, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=57, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=106),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=43, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_on', channel=4, note=89, velocity=100, time=0),
#     Message('note_on', channel=4, note=94, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=77, velocity=100, time=0),
#     Message('note_on', channel=4, note=82, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=44, velocity=89, time=106),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=44, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=99, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=79, time=46),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=89, time=46),
#     Message('note_on', channel=9, note=46, velocity=89, time=0),
#     Message('note_on', channel=9, note=40, velocity=99, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=59, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=29, velocity=0, time=45),
#     Message('note_on', channel=9, note=36, velocity=79, time=1),
#     Message('note_on', channel=1, note=29, velocity=100, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=1, note=29, velocity=0, time=45),
#     Message('note_on', channel=9, note=51, velocity=47, time=1),
#     Message('note_on', channel=1, note=32, velocity=100, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=2, note=62, velocity=0, time=45),
#     Message('note_on', channel=4, note=77, velocity=0, time=0),
#     Message('note_on', channel=2, note=70, velocity=0, time=0),
#     Message('note_on', channel=1, note=32, velocity=0, time=0),
#     Message('note_on', channel=2, note=65, velocity=0, time=0),
#     Message('note_on', channel=3, note=62, velocity=0, time=0),
#     Message('note_on', channel=3, note=70, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=4, note=82, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=4, note=89, velocity=0, time=0),
#     Message('note_on', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=3, note=65, velocity=0, time=0),
#     Message('note_on', channel=4, note=94, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=1),
#     Message('note_on', channel=1, note=34, velocity=100, time=0),
#     Message('note_on', channel=2, note=56, velocity=100, time=0),
#     Message('note_on', channel=2, note=59, velocity=100, time=0),
#     Message('note_on', channel=2, note=62, velocity=100, time=0),
#     Message('note_on', channel=2, note=67, velocity=100, time=0),
#     Message('note_on', channel=3, note=56, velocity=100, time=0),
#     Message('note_on', channel=3, note=59, velocity=100, time=0),
#     Message('note_on', channel=3, note=62, velocity=100, time=0),
#     Message('note_on', channel=3, note=67, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=4, note=71, velocity=0, time=15),
#     Message('note_on', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=79, time=31),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=99, time=46),
#     Message('note_on', channel=9, note=46, velocity=99, time=0),
#     Message('note_on', channel=9, note=40, velocity=99, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=51, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=43, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=4, note=80, velocity=100, time=0),
#     Message('note_on', channel=4, note=83, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_on', channel=4, note=91, velocity=100, time=0),
#     Message('note_on', channel=4, note=68, velocity=100, time=0),
#     Message('note_on', channel=4, note=71, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=69, time=46),
#     Message('note_on', channel=9, note=36, velocity=79, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=99, time=106),
#     Message('note_on', channel=9, note=40, velocity=99, time=0),
#     Message('note_on', channel=9, note=51, velocity=74, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=99, time=106),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=44, velocity=80, time=46),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=59, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=38, velocity=30, time=46),
#     Message('note_on', channel=9, note=38, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=50, time=46),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=60, time=46),
#     Message('note_on', channel=9, note=38, velocity=60, time=0),
#     Message('note_on', channel=9, note=51, velocity=47, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=38, velocity=0, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=4, note=79, velocity=0, time=45),
#     Message('note_on', channel=3, note=56, velocity=0, time=0),
#     Message('note_on', channel=1, note=34, velocity=0, time=0),
#     Message('note_on', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=2, note=62, velocity=0, time=0),
#     Message('note_on', channel=2, note=56, velocity=0, time=0),
#     Message('note_on', channel=3, note=67, velocity=0, time=0),
#     Message('note_on', channel=2, note=59, velocity=0, time=0),
#     Message('note_on', channel=3, note=59, velocity=0, time=0),
#     Message('note_on', channel=2, note=67, velocity=0, time=0),
#     Message('note_on', channel=4, note=80, velocity=0, time=0),
#     Message('note_on', channel=4, note=91, velocity=0, time=0),
#     Message('note_on', channel=4, note=83, velocity=0, time=0),
#     Message('note_on', channel=3, note=62, velocity=0, time=0),
#     Message('note_on', channel=4, note=71, velocity=0, time=0),
#     Message('note_on', channel=4, note=68, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=9, note=49, velocity=60, time=1),
#     Message('note_on', channel=9, note=36, velocity=60, time=0),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=1, note=26, velocity=100, time=0),
#     Message('note_on', channel=2, note=55, velocity=100, time=0),
#     Message('note_on', channel=2, note=60, velocity=100, time=0),
#     Message('note_on', channel=2, note=62, velocity=100, time=0),
#     Message('note_on', channel=3, note=55, velocity=100, time=0),
#     Message('note_on', channel=3, note=60, velocity=100, time=0),
#     Message('note_on', channel=3, note=62, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=49, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=2, note=44, velocity=100, time=42),
#     Message('note_on', channel=3, note=44, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=64),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=60, time=46),
#     Message('note_on', channel=9, note=51, velocity=93, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=46, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=89, time=46),
#     Message('note_on', channel=4, note=79, velocity=100, time=0),
#     Message('note_on', channel=4, note=84, velocity=100, time=0),
#     Message('note_on', channel=4, note=86, velocity=100, time=0),
#     Message('note_on', channel=4, note=67, velocity=100, time=0),
#     Message('note_on', channel=4, note=72, velocity=100, time=0),
#     Message('note_on', channel=4, note=74, velocity=100, time=0),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=4, note=68, velocity=100, time=42),
#     Message('note_on', channel=4, note=56, velocity=100, time=0),
#     Message('note_on', channel=9, note=44, velocity=89, time=64),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=83, time=46),
#     Message('note_on', channel=9, note=51, velocity=44, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=51, velocity=99, time=46),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=53, time=46),
#     Message('note_on', channel=9, note=36, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=63, time=46),
#     Message('note_on', channel=9, note=44, velocity=80, time=0),
#     Message('note_on', channel=9, note=44, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=9, note=59, velocity=59, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=59, velocity=99, time=46),
#     Message('note_on', channel=9, note=59, velocity=0, time=14),
#     Message('note_on', channel=9, note=40, velocity=33, time=39),
#     Message('note_on', channel=9, note=40, velocity=83, time=7),
#     Message('note_on', channel=9, note=40, velocity=0, time=7),
#     Message('note_on', channel=9, note=40, velocity=0, time=7),
#     Message('note_on', channel=9, note=40, velocity=43, time=39),
#     Message('note_on', channel=9, note=40, velocity=93, time=7),
#     Message('note_on', channel=9, note=59, velocity=99, time=0),
#     Message('note_on', channel=9, note=40, velocity=0, time=7),
#     Message('note_on', channel=9, note=59, velocity=0, time=7),
#     Message('note_on', channel=9, note=40, velocity=0, time=0),
#     Message('note_on', channel=9, note=36, velocity=63, time=46),
#     Message('note_on', channel=9, note=51, velocity=47, time=0),
#     Message('note_on', channel=9, note=51, velocity=0, time=14),
#     Message('note_on', channel=9, note=36, velocity=0, time=0),
#     Message('note_on', channel=4, note=79, velocity=0, time=45),
#     Message('note_on', channel=3, note=60, velocity=0, time=0),
#     Message('note_on', channel=4, note=74, velocity=0, time=0),
#     Message('note_on', channel=4, note=86, velocity=0, time=0),
#     Message('note_on', channel=2, note=62, velocity=0, time=0),
#     Message('note_on', channel=3, note=55, velocity=0, time=0),
#     Message('note_on', channel=2, note=60, velocity=0, time=0),
#     Message('note_on', channel=1, note=26, velocity=0, time=0),
#     Message('note_on', channel=3, note=62, velocity=0, time=0),
#     Message('note_on', channel=2, note=55, velocity=0, time=0),
#     Message('note_on', channel=4, note=72, velocity=0, time=0),
#     Message('note_on', channel=4, note=67, velocity=0, time=0),
#     Message('note_on', channel=4, note=84, velocity=0, time=0),
#     Message('note_on', channel=3, note=44, velocity=0, time=56),
#     Message('note_on', channel=2, note=44, velocity=0, time=0),
#     Message('note_on', channel=4, note=56, velocity=0, time=240),
#     Message('note_on', channel=4, note=68, velocity=0, time=0),
#     MetaMessage('end_of_track', time=0)])
# ])

# %%
# !git clone https://github.com/jason9693/midi-neural-processor
# Out:
# Cloning into 'midi-neural-processor'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 27 (delta 0), reused 0 (delta 0), pack-reused 26
# Unpacking objects: 100% (27/27), done.

# %%
# %cd midi-neural-processor/
# Out:
# /content/python-midi/midi-neural-processor

# %%
# !pip install pretty_midi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.9.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 4.9 MB/s
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.21.6)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pretty_midi) (1.15.0)
# Building wheels for collected packages: pretty-midi
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591955 sha256=f978b1b999cea9c477e81262b8e1f8c4205ee14ca0555fbc3fb6105d15d3f68e
#   Stored in directory: /root/.cache/pip/wheels/ad/74/7c/a06473ca8dcb63efb98c1e67667ce39d52100f837835ea18fa
# Successfully built pretty-midi
# Installing collected packages: pretty-midi
# Successfully installed pretty-midi-0.2.9

# %%
from processor import encode_midi

# %%
encode_midi('/content/trading-fours/Jazz Midi/ABC.mid')
# Out:
# [381,
#  68,
#  381,
#  40,
#  381,
#  44,
#  381,
#  47,
#  381,
#  68,
#  381,
#  81,
#  277,
#  196,
#  196,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  261,
#  188,
#  188,
#  261,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  44,
#  381,
#  47,
#  381,
#  52,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  381,
#  74,
#  261,
#  168,
#  172,
#  175,
#  172,
#  175,
#  260,
#  197,
#  197,
#  261,
#  381,
#  71,
#  381,
#  71,
#  381,
#  76,
#  261,
#  202,
#  261,
#  180,
#  266,
#  199,
#  199,
#  204,
#  266,
#  381,
#  68,
#  381,
#  40,
#  381,
#  44,
#  381,
#  47,
#  381,
#  68,
#  381,
#  81,
#  277,
#  196,
#  196,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  261,
#  188,
#  188,
#  261,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  44,
#  381,
#  47,
#  381,
#  52,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  381,
#  74,
#  261,
#  168,
#  172,
#  175,
#  172,
#  175,
#  260,
#  197,
#  197,
#  261,
#  381,
#  71,
#  381,
#  71,
#  381,
#  76,
#  261,
#  202,
#  261,
#  180,
#  266,
#  199,
#  199,
#  204,
#  266,
#  381,
#  66,
#  381,
#  38,
#  381,
#  42,
#  381,
#  45,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  261,
#  196,
#  196,
#  258,
#  381,
#  66,
#  381,
#  66,
#  261,
#  194,
#  194,
#  258,
#  381,
#  64,
#  381,
#  64,
#  261,
#  192,
#  192,
#  266,
#  381,
#  66,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  166,
#  170,
#  173,
#  266,
#  381,
#  68,
#  381,
#  68,
#  258,
#  196,
#  196,
#  261,
#  381,
#  66,
#  381,
#  66,
#  258,
#  194,
#  194,
#  261,
#  381,
#  64,
#  381,
#  64,
#  258,
#  192,
#  192,
#  269,
#  381,
#  66,
#  381,
#  50,
#  381,
#  54,
#  381,
#  57,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  258,
#  196,
#  196,
#  261,
#  381,
#  66,
#  381,
#  66,
#  258,
#  178,
#  182,
#  185,
#  194,
#  194,
#  261,
#  381,
#  64,
#  381,
#  64,
#  258,
#  192,
#  192,
#  269,
#  381,
#  66,
#  381,
#  38,
#  381,
#  42,
#  381,
#  45,
#  381,
#  66,
#  381,
#  81,
#  277,
#  209,
#  277,
#  194,
#  166,
#  170,
#  173,
#  194,
#  277,
#  381,
#  68,
#  381,
#  40,
#  381,
#  44,
#  381,
#  47,
#  381,
#  68,
#  381,
#  81,
#  277,
#  196,
#  196,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  261,
#  188,
#  188,
#  261,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  44,
#  381,
#  47,
#  381,
#  52,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  381,
#  74,
#  261,
#  168,
#  172,
#  175,
#  172,
#  175,
#  260,
#  197,
#  197,
#  261,
#  381,
#  71,
#  381,
#  71,
#  381,
#  76,
#  261,
#  202,
#  261,
#  180,
#  266,
#  199,
#  199,
#  204,
#  266,
#  381,
#  68,
#  381,
#  40,
#  381,
#  44,
#  381,
#  47,
#  381,
#  68,
#  381,
#  81,
#  277,
#  196,
#  196,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  381,
#  60,
#  261,
#  188,
#  188,
#  261,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  44,
#  381,
#  47,
#  381,
#  52,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  381,
#  74,
#  261,
#  168,
#  172,
#  175,
#  172,
#  175,
#  260,
#  197,
#  197,
#  261,
#  381,
#  71,
#  381,
#  71,
#  381,
#  76,
#  261,
#  202,
#  261,
#  180,
#  266,
#  199,
#  199,
#  204,
#  266,
#  381,
#  66,
#  381,
#  38,
#  381,
#  42,
#  381,
#  45,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  261,
#  196,
#  196,
#  258,
#  381,
#  66,
#  381,
#  66,
#  261,
#  194,
#  194,
#  258,
#  381,
#  64,
#  381,
#  64,
#  261,
#  192,
#  192,
#  266,
#  381,
#  66,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  166,
#  170,
#  173,
#  266,
#  381,
#  68,
#  381,
#  68,
#  258,
#  196,
#  196,
#  261,
#  381,
#  66,
#  381,
#  66,
#  258,
#  194,
#  194,
#  261,
#  381,
#  64,
#  381,
#  64,
#  258,
#  192,
#  192,
#  269,
#  381,
#  66,
#  381,
#  50,
#  381,
#  54,
#  381,
#  57,
#  381,
#  66,
#  381,
#  81,
#  277,
#  194,
#  194,
#  209,
#  266,
#  381,
#  68,
#  381,
#  68,
#  258,
#  196,
#  196,
#  261,
#  381,
#  66,
#  381,
#  66,
#  258,
#  178,
#  182,
#  185,
#  194,
#  194,
#  261,
#  381,
#  64,
#  381,
#  64,
#  258,
#  192,
#  192,
#  269,
#  381,
#  66,
#  381,
#  38,
#  381,
#  42,
#  381,
#  45,
#  381,
#  66,
#  381,
#  81,
#  277,
#  209,
#  277,
#  194,
#  166,
#  170,
#  173,
#  194,
#  277,
#  381,
#  64,
#  381,
#  48,
#  381,
#  55,
#  381,
#  52,
#  381,
#  64,
#  381,
#  81,
#  277,
#  192,
#  192,
#  209,
#  266,
#  381,
#  64,
#  381,
#  64,
#  266,
#  192,
#  192,
#  261,
#  381,
#  64,
#  381,
#  64,
#  266,
#  192,
#  192,
#  261,
#  381,
#  64,
#  381,
#  64,
#  266,
#  192,
#  192,
#  261,
#  381,
#  66,
#  381,
#  66,
#  261,
#  176,
#  183,
#  180,
#  260,
#  194,
#  194,
#  261,
#  381,
#  67,
#  381,
#  67,
#  266,
#  195,
#  195,
#  261,
#  381,
#  69,
#  381,
#  69,
#  266,
#  197,
#  197,
#  261,
#  381,
#  67,
#  381,
#  60,
#  381,
#  55,
#  381,
#  67,
#  381,
#  81,
#  266,
#  195,
#  195,
#  261,
#  381,
#  66,
#  381,
#  66,
#  261,
#  209,
#  261,
#  194,
#  194,
#  261,
#  381,
#  64,
#  381,
#  64,
#  266,
#  188,
#  183,
#  192,
#  192,
#  261,
#  381,
#  62,
#  381,
#  62,
#  266,
#  190,
#  190,
#  261,
#  381,
#  64,
#  381,
#  58,
#  381,
#  55,
#  381,
#  64,
#  381,
#  81,
#  277,
#  209,
#  277,
#  192,
#  186,
#  183,
#  192,
#  277,
#  381,
#  67,
#  381,
#  51,
#  381,
#  55,
#  381,
#  58,
#  381,
#  67,
#  381,
#  81,
#  277,
#  195,
#  195,
#  209,
#  266,
#  381,
#  67,
#  381,
#  67,
#  266,
#  195,
#  195,
#  261,
#  381,
#  67,
#  381,
#  67,
#  266,
#  195,
#  195,
#  261,
#  381,
#  67,
#  381,
#  67,
#  266,
#  195,
#  195,
#  261,
#  381,
#  69,
#  381,
#  69,
#  261,
#  179,
#  183,
#  186,
#  260,
#  197,
#  197,
#  261,
#  381,
#  70,
#  381,
#  70,
#  266,
#  198,
#  198,
#  261,
#  381,
#  72,
#  381,
#  72,
#  266,
#  200,
#  200,
#  261,
#  381,
#  70,
#  381,
#  60,
#  381,
#  55,
#  381,
#  70,
#  381,
#  81,
#  266,
#  198,
#  198,
#  261,
#  381,
#  69,
#  381,
#  69,
#  261,
#  209,
#  261,
#  197,
#  197,
#  261,
#  381,
#  67,
#  381,
#  67,
#  266,
#  188,
#  183,
#  195,
#  195,
#  261,
#  381,
#  65,
#  381,
#  65,
#  266,
#  193,
#  193,
#  261,
#  381,
#  67,
#  381,
#  58,
#  381,
#  55,
#  381,
#  67,
#  381,
#  81,
#  277,
#  209,
#  277,
#  195,
#  186,
#  183,
#  195,
#  277,
#  381,
#  68,
#  381,
#  52,
#  381,
#  56,
#  381,
#  59,
#  381,
#  68,
#  381,
#  81,
#  381,
#  77,
#  277,
#  196,
#  196,
#  209,
#  205,
#  266,
#  381,
#  68,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  266,
#  196,
#  196,
#  261,
#  381,
#  68,
#  381,
#  68,
#  381,
#  77,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  261,
#  205,
#  180,
#  184,
#  187,
#  260,
#  197,
#  197,
#  261,
#  381,
#  71,
#  381,
#  71,
#  277,
#  199,
#  199,
#  266,
#  381,
#  71,
#  381,
#  71,
#  381,
#  77,
#  266,
#  199,
#  199,
#  261,
#  381,
#  76,
#  381,
#  76,
#  261,
#  205,
#  261,
#  204,
#  204,
#  261,
#  381,
#  68,
#  381,
#  68,
#  277,
#  196,
#  196,
#  266,
#  381,
#  68,
#  381,
#  68,
#  381,
#  77,
#  266,
#  196,
#  196,
#  261,
#  381,
#  69,
#  381,
#  69,
#  261,
#  205,
#  261,
#  197,
#  197,
#  ...]

# %%
def midiToText(midifile):
    #load midi file
    midi_data = pretty_midi.PrettyMIDI(midifile)
    #create list of notes for each instrument in midi file
    total_note_list = []
    #loop over all instruments in midi file
    for i in range(len(midi_data.instruments[:])):
        #create list of notes for each instrument
        single_instrument_note_list = []
        for note in midi_data.instruments[i].notes[:]:
            #change note's pitch from numerical to text value
            note.pitch = pretty_midi.note_number_to_name(note.pitch)
            single_instrument_note_list.append(note)
        total_note_list.append(single_instrument_note_list)
    return total_note_list
